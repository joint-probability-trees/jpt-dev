# %% [markdown]
# # Regression
#
# This example will guide through a very noisy regression problem. First we have to create the regression data. The data will originate from
# the function $x \cdot sin(x)$.

# %%
import pandas as pd
import numpy as np
import logging

logging.getLogger("/jpt").setLevel(0)
def f(x):
    return x * np.sin(x)

def generate_data(func, x_lower, x_upper, n):
    '''
    Generate a ``DataFrame`` of ``n`` data samples with additive noise from the function ``func``.
    '''
    X = np.atleast_2d(np.random.uniform(-20, 0.0, size=int(n / 2))).T
    X = np.vstack((np.atleast_2d(np.random.uniform(0, 10.0, size=int(n / 2))).T, X))
    X = X.astype(np.float32)
    X = np.array(list(sorted(X)))

    # Observations
    y = func(X).ravel()

    # Add some noise
    dy = 1.5 + .5 * np.random.random(y.shape)
    y += np.random.normal(0, dy)
    y = y.astype(np.float32)

    return pd.DataFrame(data={'x': X.ravel(), 'y': y})

df = generate_data(f, -20, 10, 1000)
df
# Out:
#              x          y
# 0   -19.935032  16.376917
# 1   -19.895292  17.563318
# 2   -19.891935  17.496082
# 3   -19.886454  16.961576
# 4   -19.867498  16.860767
# ..         ...        ...
# 995   9.837988  -4.018869
# 996   9.845700  -5.032810
# 997   9.873614  -9.529246
# 998   9.883554  -5.090649
# 999   9.998951  -5.671313
#
# [1000 rows x 2 columns]

# %% [markdown]
# Lets have a look at the data visually:

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.plot(df['x'].values, df['y'].values, '.', markersize=5, label='Training data')
plt.show()

# %% [markdown]
# We can clearly see the original function, and we can observe that there is more variance towards higher x. In general, we don't want a model that assumes independent noise, and we don't want to specify much prior knowledge since it is only available rarely. Let's specify a JPT that focuses on predicting y accurately.

# %%
from jpt.variables import NumericVariable, VariableMap
from jpt.trees import JPT

# Construct the variables, soften up x via blur
varx = NumericVariable('x', blur=.05)
vary = NumericVariable('y')

# enable a focus on the parameters for y with the targets keyword
jpt = JPT(variables=[varx, vary], targets=[vary], min_samples_leaf=.01, min_impurity_improvement=0.01)

jpt.learn(data=df)
# Out:
# JPT
# <DecisionNode #0 x = [x < 6.480; 6.480 ≤ x]; parent-#: None; #children: 2>
#     <DecisionNode #1 x = [x < -19.192; -19.192 ≤ x]; parent-#: 0; #children: 2>
#         <Leaf #3; parent: <DecisionNode #1>>
#         <DecisionNode #4 x = [x < -15.924; -15.924 ≤ x]; parent-#: 1; #children: 2>
#             <DecisionNode #7 x = [x < -18.476; -18.476 ≤ x]; parent-#: 4; #children: 2>
#                 <DecisionNode #13 x = [x < -18.842; -18.842 ≤ x]; parent-#: 7; #children: 2>
#                     <Leaf #21; parent: <DecisionNode #13>>
#                     <Leaf #22; parent: <DecisionNode #13>>
#                 <DecisionNode #14 x = [x < -16.521; -16.521 ≤ x]; parent-#: 7; #children: 2>
#                     <DecisionNode #23 x = [x < -17.792; -17.792 ≤ x]; parent-#: 14; #children: 2>
#                         <Leaf #33; parent: <DecisionNode #23>>
#                         <DecisionNode #34 x = [x < -17.227; -17.227 ≤ x]; parent-#: 23; #children: 2>
#                             <Leaf #43; parent: <DecisionNode #34>>
#                             <Leaf #44; parent: <DecisionNode #34>>
#                     <Leaf #24; parent: <DecisionNode #14>>
#             <DecisionNode #8 x = [x < -12.990; -12.990 ≤ x]; parent-#: 4; #children: 2>
#                 <DecisionNode #15 x = [x < -15.221; -15.221 ≤ x]; parent-#: 8; #children: 2>
#                     <Leaf #25; parent: <DecisionNode #15>>
#                     <DecisionNode #26 x = [x < -13.393; -13.393 ≤ x]; parent-#: 15; #children: 2>
#                         <DecisionNode #35 x = [x < -14.999; -14.999 ≤ x]; parent-#: 26; #children: 2>
#                             <Leaf #45; parent: <DecisionNode #35>>
#                             <DecisionNode #46 x = [x < -13.784; -13.784 ≤ x]; parent-#: 35; #children: 2>
#                                 <DecisionNode #55 x = [x < -14.426; -14.426 ≤ x]; parent-#: 46; #children: 2>
#                                     <Leaf #65; parent: <DecisionNode #55>>
#                                     <Leaf #66; parent: <DecisionNode #55>>
#                                 <Leaf #56; parent: <DecisionNode #46>>
#                         <Leaf #36; parent: <DecisionNode #26>>
#                 <DecisionNode #16 x = [x < -9.715; -9.715 ≤ x]; parent-#: 8; #children: 2>
#                     <DecisionNode #27 x = [x < -12.172; -12.172 ≤ x]; parent-#: 16; #children: 2>
#                         <Leaf #37; parent: <DecisionNode #27>>
#                         <DecisionNode #38 x = [x < -10.312; -10.312 ≤ x]; parent-#: 27; #children: 2>
#                             <DecisionNode #47 x = [x < -11.828; -11.828 ≤ x]; parent-#: 38; #children: 2>
#                                 <Leaf #57; parent: <DecisionNode #47>>
#                                 <DecisionNode #58 x = [x < -10.675; -10.675 ≤ x]; parent-#: 47; #children: 2>
#                                     <DecisionNode #67 x = [x < -11.421; -11.421 ≤ x]; parent-#: 58; #children: 2>
#                                         <Leaf #77; parent: <DecisionNode #67>>
#                                         <DecisionNode #78 x = [x < -10.922; -10.922 ≤ x]; parent-#: 67; #children: 2>
#                                             <Leaf #87; parent: <DecisionNode #78>>
#                                             <Leaf #88; parent: <DecisionNode #78>>
#                                     <Leaf #68; parent: <DecisionNode #58>>
#                             <Leaf #48; parent: <DecisionNode #38>>
#                     <DecisionNode #28 x = [x < -6.774; -6.774 ≤ x]; parent-#: 16; #children: 2>
#                         <DecisionNode #39 x = [x < -8.923; -8.923 ≤ x]; parent-#: 28; #children: 2>
#                             <Leaf #49; parent: <DecisionNode #39>>
#                             <DecisionNode #50 x = [x < -7.396; -7.396 ≤ x]; parent-#: 39; #children: 2>
#                                 <DecisionNode #59 x = [x < -8.376; -8.376 ≤ x]; parent-#: 50; #children: 2>
#                                     <Leaf #69; parent: <DecisionNode #59>>
#                                     <Leaf #70; parent: <DecisionNode #59>>
#                                 <Leaf #60; parent: <DecisionNode #50>>
#                         <DecisionNode #40 x = [x < 3.502; 3.502 ≤ x]; parent-#: 28; #children: 2>
#                             <DecisionNode #51 x = [x < -3.372; -3.372 ≤ x]; parent-#: 40; #children: 2>
#                                 <DecisionNode #61 x = [x < -6.066; -6.066 ≤ x]; parent-#: 51; #children: 2>
#                                     <Leaf #71; parent: <DecisionNode #61>>
#                                     <DecisionNode #72 x = [x < -3.933; -3.933 ≤ x]; parent-#: 61; #children: 2>
#                                         <DecisionNode #79 x = [x < -5.189; -5.189 ≤ x]; parent-#: 72; #children: 2>
#                                             <DecisionNode #89 x = [x < -5.451; -5.451 ≤ x]; parent-#: 79; #children: 2>
#                                                 <Leaf #97; parent: <DecisionNode #89>>
#                                                 <Leaf #98; parent: <DecisionNode #89>>
#                                             <DecisionNode #90 x = [x < -4.307; -4.307 ≤ x]; parent-#: 79; #children: 2>
#                                                 <Leaf #99; parent: <DecisionNode #90>>
#                                                 <Leaf #100; parent: <DecisionNode #90>>
#                                         <Leaf #80; parent: <DecisionNode #72>>
#                                 <DecisionNode #62 x = [x < 3.219; 3.219 ≤ x]; parent-#: 51; #children: 2>
#                                     <DecisionNode #73 x = [x < 1.499; 1.499 ≤ x]; parent-#: 62; #children: 2>
#                                         <DecisionNode #81 x = [x < -1.077; -1.077 ≤ x]; parent-#: 73; #children: 2>
#                                             <DecisionNode #91 x = [x < -2.431; -2.431 ≤ x]; parent-#: 81; #children: 2>
#                                                 <Leaf #101; parent: <DecisionNode #91>>
#                                                 <DecisionNode #102 x = [x < -2.034; -2.034 ≤ x]; parent-#: 91; #children: 2>
#                                                     <Leaf #107; parent: <DecisionNode #102>>
#                                                     <DecisionNode #108 x = [x < -1.509; -1.509 ≤ x]; parent-#: 102; #children: 2>
#                                                         <Leaf #111; parent: <DecisionNode #108>>
#                                                         <Leaf #112; parent: <DecisionNode #108>>
#                                             <Leaf #92; parent: <DecisionNode #81>>
#                                         <DecisionNode #82 x = [x < 2.632; 2.632 ≤ x]; parent-#: 73; #children: 2>
#                                             <DecisionNode #93 x = [x < 1.737; 1.737 ≤ x]; parent-#: 82; #children: 2>
#                                                 <Leaf #103; parent: <DecisionNode #93>>
#                                                 <DecisionNode #104 x = [x < 1.946; 1.946 ≤ x]; parent-#: 93; #children: 2>
#                                                     <Leaf #109; parent: <DecisionNode #104>>
#                                                     <Leaf #110; parent: <DecisionNode #104>>
#                                             <Leaf #94; parent: <DecisionNode #82>>
#                                     <Leaf #74; parent: <DecisionNode #62>>
#                             <DecisionNode #52 x = [x < 6.116; 6.116 ≤ x]; parent-#: 40; #children: 2>
#                                 <DecisionNode #63 x = [x < 4.081; 4.081 ≤ x]; parent-#: 52; #children: 2>
#                                     <DecisionNode #75 x = [x < 3.835; 3.835 ≤ x]; parent-#: 63; #children: 2>
#                                         <Leaf #83; parent: <DecisionNode #75>>
#                                         <Leaf #84; parent: <DecisionNode #75>>
#                                     <DecisionNode #76 x = [x < 5.729; 5.729 ≤ x]; parent-#: 63; #children: 2>
#                                         <DecisionNode #85 x = [x < 4.389; 4.389 ≤ x]; parent-#: 76; #children: 2>
#                                             <Leaf #95; parent: <DecisionNode #85>>
#                                             <DecisionNode #96 x = [x < 5.322; 5.322 ≤ x]; parent-#: 85; #children: 2>
#                                                 <Leaf #105; parent: <DecisionNode #96>>
#                                                 <Leaf #106; parent: <DecisionNode #96>>
#                                         <Leaf #86; parent: <DecisionNode #76>>
#                                 <Leaf #64; parent: <DecisionNode #52>>
#     <DecisionNode #2 x = [x < 9.163; 9.163 ≤ x]; parent-#: 0; #children: 2>
#         <DecisionNode #5 x = [x < 8.722; 8.722 ≤ x]; parent-#: 2; #children: 2>
#             <DecisionNode #9 x = [x < 7.268; 7.268 ≤ x]; parent-#: 5; #children: 2>
#                 <DecisionNode #17 x = [x < 6.866; 6.866 ≤ x]; parent-#: 9; #children: 2>
#                     <Leaf #29; parent: <DecisionNode #17>>
#                     <Leaf #30; parent: <DecisionNode #17>>
#                 <DecisionNode #18 x = [x < 8.458; 8.458 ≤ x]; parent-#: 9; #children: 2>
#                     <DecisionNode #31 x = [x < 7.532; 7.532 ≤ x]; parent-#: 18; #children: 2>
#                         <Leaf #41; parent: <DecisionNode #31>>
#                         <DecisionNode #42 x = [x < 7.857; 7.857 ≤ x]; parent-#: 31; #children: 2>
#                             <Leaf #53; parent: <DecisionNode #42>>
#                             <Leaf #54; parent: <DecisionNode #42>>
#                     <Leaf #32; parent: <DecisionNode #18>>
#             <Leaf #10; parent: <DecisionNode #5>>
#         <DecisionNode #6 x = [x < 9.727; 9.727 ≤ x]; parent-#: 2; #children: 2>
#             <DecisionNode #11 x = [x < 9.351; 9.351 ≤ x]; parent-#: 6; #children: 2>
#                 <Leaf #19; parent: <DecisionNode #11>>
#                 <Leaf #20; parent: <DecisionNode #11>>
#             <Leaf #12; parent: <DecisionNode #6>>
#
# JPT stats: #innernodes = 56, #leaves = 57 (113 total)

# %% [markdown]
# Since the data is 2D we can get a visual representation of the predictions of the JPT. Let's plot the predictions and get an idea of the distribution. We will plot the expectation of y for every datapoint on the x-axis and confidence intervals that explain 95% of the variance.

# %%
# Mesh the input space for evaluations of the real function,
# the prediction and its MSE
xx = np.atleast_2d(np.linspace(-20, 15, 500)).astype(np.float32).T

# Apply the JPT model
confidence = .95
conf_level = 0.95
my_predictions = [jpt.posterior([vary], evidence={varx: x_}, fail_on_unsatisfiability=False) for x_ in xx.ravel()]
y_pred_ = [(p[vary].expectation() if p is not None else None) for p in my_predictions]
y_lower_ = [(p[vary].ppf.eval((1 - conf_level) / 2) if p is not None else None) for p in my_predictions]
y_upper_ = [(p[vary].ppf.eval(1 - (1 - conf_level) / 2) if p is not None else None) for p in my_predictions]

# posterior = jpt.posterior([varx], {vary: 0})

# Plot the function, the prediction and the 90% confidence interval based on the MSE
plt.plot(xx, f(xx), color='black', linestyle=':', linewidth='2', label=r'$f(x) = x\,\sin(x)$')
plt.plot(df['x'].values, df['y'].values, '.', color='gray', markersize=5, label='Training data')
plt.plot(xx, y_pred_, 'm-', label='JPT Prediction', linewidth=2)
plt.plot(xx, y_lower_, 'y--', label='%.1f%% Confidence bands' % (confidence * 100))
plt.plot(xx, y_upper_, 'y--')
# plt.plot(xx, np.asarray(posterior.distributions[varx].pdf.multi_eval(xx.ravel().astype(np.float64))),
#          label='Posterior')
plt.plot(xx, np.array([jpt.pdf(VariableMap([(varx, x_), (vary, 0)])) for x_ in xx.ravel().astype(np.float64)]),
         label='Posterior')

plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.ylim(-10, 20)
plt.xlim(-25, 15)
plt.legend(loc='upper left')
plt.title(r'2D Regression Example ($\vartheta=%.2f\%%$)' % (confidence * 100))
plt.grid()

plt.show()

# %% [markdown]
# As we can see the expectations and variances predicted by the JPT characterize this dataset well and the variance even adjusts to the different x values. Impressive!
