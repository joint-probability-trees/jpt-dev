# %% [markdown]
# # Regression
#
# This example will guide through a very noisy regression problem. First we have to create the regression data. The data will originate from
# the function $x \cdot sin(x)$.

# %%
import pandas as pd
import numpy as np
import logging

logging.getLogger("/jpt").setLevel(0)
def f(x):
    return x * np.sin(x)

def generate_data(func, x_lower, x_upper, n):
    '''
    Generate a ``DataFrame`` of ``n`` data samples with additive noise from the function ``func``.
    '''
    X = np.atleast_2d(np.random.uniform(-20, 0.0, size=int(n / 2))).T
    X = np.vstack((np.atleast_2d(np.random.uniform(0, 10.0, size=int(n / 2))).T, X))
    X = X.astype(np.float32)
    X = np.array(list(sorted(X)))

    # Observations
    y = func(X).ravel()

    # Add some noise
    dy = 1.5 + .5 * np.random.random(y.shape)
    y += np.random.normal(0, dy)
    y = y.astype(np.float32)

    return pd.DataFrame(data={'x': X.ravel(), 'y': y})

df = generate_data(f, -20, 10, 1000)
df
# Out:
#              x          y
# 0   -19.928883  17.304375
# 1   -19.823929  17.070272
# 2   -19.791965  14.570556
# 3   -19.753151  14.920757
# 4   -19.745525  17.015135
# ..         ...        ...
# 995   9.842395  -2.665823
# 996   9.878265   1.414980
# 997   9.903580  -5.722112
# 998   9.940924  -6.882326
# 999   9.975057  -5.546760
#
# [1000 rows x 2 columns]

# %% [markdown]
# Lets have a look at the data visually:

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.plot(df['x'].values, df['y'].values, '.', markersize=5, label='Training data')
plt.show()

# %% [markdown]
# We can clearly see the original function, and we can observe that there is more variance towards higher x. In general, we don't want a model that assumes independent noise, and we don't want to specify much prior knowledge since it is only available rarely. Let's specify a JPT that focuses on predicting y accurately.

# %%
from jpt.variables import NumericVariable, VariableMap
from jpt.trees import JPT

# Construct the variables, soften up x via blur
varx = NumericVariable('x', blur=.05)
vary = NumericVariable('y')

# enable a focus on the parameters for y with the targets keyword
jpt = JPT(variables=[varx, vary], targets=[vary], min_samples_leaf=.01, min_impurity_improvement=0.01)

jpt.learn(data=df)
# Out:
# JPT
# <DecisionNode #0 x = [x < -15.853; -15.853 ≤ x]; parent-#: None; #children: 2>
#     <DecisionNode #1 x = [x < -18.791; -18.791 ≤ x]; parent-#: 0; #children: 2>
#         <DecisionNode #3 x = [x < -19.414; -19.414 ≤ x]; parent-#: 1; #children: 2>
#             <Leaf #7; parent: <DecisionNode #3>>
#             <Leaf #8; parent: <DecisionNode #3>>
#         <DecisionNode #4 x = [x < -18.484; -18.484 ≤ x]; parent-#: 1; #children: 2>
#             <Leaf #9; parent: <DecisionNode #4>>
#             <DecisionNode #10 x = [x < -16.488; -16.488 ≤ x]; parent-#: 4; #children: 2>
#                 <DecisionNode #15 x = [x < -18.023; -18.023 ≤ x]; parent-#: 10; #children: 2>
#                     <Leaf #25; parent: <DecisionNode #15>>
#                     <DecisionNode #26 x = [x < -16.696; -16.696 ≤ x]; parent-#: 15; #children: 2>
#                         <DecisionNode #37 x = [x < -17.207; -17.207 ≤ x]; parent-#: 26; #children: 2>
#                             <Leaf #51; parent: <DecisionNode #37>>
#                             <Leaf #52; parent: <DecisionNode #37>>
#                         <Leaf #38; parent: <DecisionNode #26>>
#                 <Leaf #16; parent: <DecisionNode #10>>
#     <DecisionNode #2 x = [x < -12.945; -12.945 ≤ x]; parent-#: 0; #children: 2>
#         <DecisionNode #5 x = [x < -15.065; -15.065 ≤ x]; parent-#: 2; #children: 2>
#             <DecisionNode #11 x = [x < -15.313; -15.313 ≤ x]; parent-#: 5; #children: 2>
#                 <Leaf #17; parent: <DecisionNode #11>>
#                 <Leaf #18; parent: <DecisionNode #11>>
#             <DecisionNode #12 x = [x < -13.579; -13.579 ≤ x]; parent-#: 5; #children: 2>
#                 <DecisionNode #19 x = [x < -14.538; -14.538 ≤ x]; parent-#: 12; #children: 2>
#                     <Leaf #27; parent: <DecisionNode #19>>
#                     <DecisionNode #28 x = [x < -13.928; -13.928 ≤ x]; parent-#: 19; #children: 2>
#                         <Leaf #39; parent: <DecisionNode #28>>
#                         <Leaf #40; parent: <DecisionNode #28>>
#                 <Leaf #20; parent: <DecisionNode #12>>
#         <DecisionNode #6 x = [x < -9.684; -9.684 ≤ x]; parent-#: 2; #children: 2>
#             <DecisionNode #13 x = [x < -12.223; -12.223 ≤ x]; parent-#: 6; #children: 2>
#                 <DecisionNode #21 x = [x < -12.578; -12.578 ≤ x]; parent-#: 13; #children: 2>
#                     <Leaf #29; parent: <DecisionNode #21>>
#                     <Leaf #30; parent: <DecisionNode #21>>
#                 <DecisionNode #22 x = [x < -10.254; -10.254 ≤ x]; parent-#: 13; #children: 2>
#                     <DecisionNode #31 x = [x < -11.586; -11.586 ≤ x]; parent-#: 22; #children: 2>
#                         <Leaf #41; parent: <DecisionNode #31>>
#                         <DecisionNode #42 x = [x < -10.878; -10.878 ≤ x]; parent-#: 31; #children: 2>
#                             <Leaf #53; parent: <DecisionNode #42>>
#                             <Leaf #54; parent: <DecisionNode #42>>
#                     <Leaf #32; parent: <DecisionNode #22>>
#             <DecisionNode #14 x = [x < 6.568; 6.568 ≤ x]; parent-#: 6; #children: 2>
#                 <DecisionNode #23 x = [x < -6.493; -6.493 ≤ x]; parent-#: 14; #children: 2>
#                     <DecisionNode #33 x = [x < -8.851; -8.851 ≤ x]; parent-#: 23; #children: 2>
#                         <Leaf #43; parent: <DecisionNode #33>>
#                         <DecisionNode #44 x = [x < -7.147; -7.147 ≤ x]; parent-#: 33; #children: 2>
#                             <DecisionNode #55 x = [x < -8.539; -8.539 ≤ x]; parent-#: 44; #children: 2>
#                                 <Leaf #65; parent: <DecisionNode #55>>
#                                 <DecisionNode #66 x = [x < -7.553; -7.553 ≤ x]; parent-#: 55; #children: 2>
#                                     <Leaf #79; parent: <DecisionNode #66>>
#                                     <Leaf #80; parent: <DecisionNode #66>>
#                             <Leaf #56; parent: <DecisionNode #44>>
#                     <DecisionNode #34 x = [x < 3.521; 3.521 ≤ x]; parent-#: 23; #children: 2>
#                         <DecisionNode #45 x = [x < -3.659; -3.659 ≤ x]; parent-#: 34; #children: 2>
#                             <DecisionNode #57 x = [x < -6.067; -6.067 ≤ x]; parent-#: 45; #children: 2>
#                                 <Leaf #67; parent: <DecisionNode #57>>
#                                 <DecisionNode #68 x = [x < -5.318; -5.318 ≤ x]; parent-#: 57; #children: 2>
#                                     <Leaf #81; parent: <DecisionNode #68>>
#                                     <DecisionNode #82 x = [x < -4.245; -4.245 ≤ x]; parent-#: 68; #children: 2>
#                                         <Leaf #93; parent: <DecisionNode #82>>
#                                         <Leaf #94; parent: <DecisionNode #82>>
#                             <DecisionNode #58 x = [x < 3.166; 3.166 ≤ x]; parent-#: 45; #children: 2>
#                                 <DecisionNode #69 x = [x < -3.030; -3.030 ≤ x]; parent-#: 58; #children: 2>
#                                     <Leaf #83; parent: <DecisionNode #69>>
#                                     <DecisionNode #84 x = [x < -1.129; -1.129 ≤ x]; parent-#: 69; #children: 2>
#                                         <DecisionNode #95 x = [x < -2.438; -2.438 ≤ x]; parent-#: 84; #children: 2>
#                                             <Leaf #103; parent: <DecisionNode #95>>
#                                             <Leaf #104; parent: <DecisionNode #95>>
#                                         <DecisionNode #96 x = [x < 0.537; 0.537 ≤ x]; parent-#: 84; #children: 2>
#                                             <DecisionNode #105 x = [x < -0.459; -0.459 ≤ x]; parent-#: 96; #children: 2>
#                                                 <Leaf #111; parent: <DecisionNode #105>>
#                                                 <DecisionNode #112 x = [x < 0.231; 0.231 ≤ x]; parent-#: 105; #children: 2>
#                                                     <Leaf #113; parent: <DecisionNode #112>>
#                                                     <Leaf #114; parent: <DecisionNode #112>>
#                                             <Leaf #106; parent: <DecisionNode #96>>
#                                 <Leaf #70; parent: <DecisionNode #58>>
#                         <DecisionNode #46 x = [x < 5.835; 5.835 ≤ x]; parent-#: 34; #children: 2>
#                             <DecisionNode #59 x = [x < 3.898; 3.898 ≤ x]; parent-#: 46; #children: 2>
#                                 <Leaf #71; parent: <DecisionNode #59>>
#                                 <DecisionNode #72 x = [x < 5.478; 5.478 ≤ x]; parent-#: 59; #children: 2>
#                                     <DecisionNode #85 x = [x < 4.420; 4.420 ≤ x]; parent-#: 72; #children: 2>
#                                         <DecisionNode #97 x = [x < 4.161; 4.161 ≤ x]; parent-#: 85; #children: 2>
#                                             <Leaf #107; parent: <DecisionNode #97>>
#                                             <Leaf #108; parent: <DecisionNode #97>>
#                                         <DecisionNode #98 x = [x < 4.679; 4.679 ≤ x]; parent-#: 85; #children: 2>
#                                             <Leaf #109; parent: <DecisionNode #98>>
#                                             <Leaf #110; parent: <DecisionNode #98>>
#                                     <Leaf #86; parent: <DecisionNode #72>>
#                             <DecisionNode #60 x = [x < 6.415; 6.415 ≤ x]; parent-#: 46; #children: 2>
#                                 <Leaf #73; parent: <DecisionNode #60>>
#                                 <Leaf #74; parent: <DecisionNode #60>>
#                 <DecisionNode #24 x = [x < 9.181; 9.181 ≤ x]; parent-#: 14; #children: 2>
#                     <DecisionNode #35 x = [x < 7.041; 7.041 ≤ x]; parent-#: 24; #children: 2>
#                         <DecisionNode #47 x = [x < 6.897; 6.897 ≤ x]; parent-#: 35; #children: 2>
#                             <Leaf #61; parent: <DecisionNode #47>>
#                             <Leaf #62; parent: <DecisionNode #47>>
#                         <DecisionNode #48 x = [x < 8.504; 8.504 ≤ x]; parent-#: 35; #children: 2>
#                             <DecisionNode #63 x = [x < 7.660; 7.660 ≤ x]; parent-#: 48; #children: 2>
#                                 <DecisionNode #75 x = [x < 7.230; 7.230 ≤ x]; parent-#: 63; #children: 2>
#                                     <Leaf #87; parent: <DecisionNode #75>>
#                                     <DecisionNode #88 x = [x < 7.403; 7.403 ≤ x]; parent-#: 75; #children: 2>
#                                         <Leaf #99; parent: <DecisionNode #88>>
#                                         <Leaf #100; parent: <DecisionNode #88>>
#                                 <DecisionNode #76 x = [x < 8.310; 8.310 ≤ x]; parent-#: 63; #children: 2>
#                                     <DecisionNode #89 x = [x < 8.095; 8.095 ≤ x]; parent-#: 76; #children: 2>
#                                         <Leaf #101; parent: <DecisionNode #89>>
#                                         <Leaf #102; parent: <DecisionNode #89>>
#                                     <Leaf #90; parent: <DecisionNode #76>>
#                             <DecisionNode #64 x = [x < 8.928; 8.928 ≤ x]; parent-#: 48; #children: 2>
#                                 <DecisionNode #77 x = [x < 8.705; 8.705 ≤ x]; parent-#: 64; #children: 2>
#                                     <Leaf #91; parent: <DecisionNode #77>>
#                                     <Leaf #92; parent: <DecisionNode #77>>
#                                 <Leaf #78; parent: <DecisionNode #64>>
#                     <DecisionNode #36 x = [x < 9.652; 9.652 ≤ x]; parent-#: 24; #children: 2>
#                         <Leaf #49; parent: <DecisionNode #36>>
#                         <Leaf #50; parent: <DecisionNode #36>>
#
# JPT stats: #innernodes = 57, #leaves = 58 (115 total)

# %% [markdown]
# Since the data is 2D we can get a visual representation of the predictions of the JPT. Let's plot the predictions and get an idea of the distribution. We will plot the expectation of y for every datapoint on the x-axis and confidence intervals that explain 95% of the variance.

# %%
# Mesh the input space for evaluations of the real function,
# the prediction and its MSE
xx = np.atleast_2d(np.linspace(-20, 15, 500)).astype(np.float32).T

# Apply the JPT model
confidence = .95
conf_level = 0.95
my_predictions = [jpt.posterior([vary], evidence={varx: x_}, fail_on_unsatisfiability=False) for x_ in xx.ravel()]
y_pred_ = [(p[vary].expectation() if p is not None else None) for p in my_predictions]
y_lower_ = [(p[vary].ppf.eval((1 - conf_level) / 2) if p is not None else None) for p in my_predictions]
y_upper_ = [(p[vary].ppf.eval(1 - (1 - conf_level) / 2) if p is not None else None) for p in my_predictions]

# posterior = jpt.posterior([varx], {vary: 0})

# Plot the function, the prediction and the 90% confidence interval based on the MSE
plt.plot(xx, f(xx), color='black', linestyle=':', linewidth='2', label=r'$f(x) = x\,\sin(x)$')
plt.plot(df['x'].values, df['y'].values, '.', color='gray', markersize=5, label='Training data')
plt.plot(xx, y_pred_, 'm-', label='JPT Prediction', linewidth=2)
plt.plot(xx, y_lower_, 'y--', label='%.1f%% Confidence bands' % (confidence * 100))
plt.plot(xx, y_upper_, 'y--')
# plt.plot(xx, np.asarray(posterior.distributions[varx].pdf.multi_eval(xx.ravel().astype(np.float64))),
#          label='Posterior')
plt.plot(xx, np.array([jpt.pdf(VariableMap([(varx, x_), (vary, 0)])) for x_ in xx.ravel().astype(np.float64)]),
         label='Posterior')

plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.ylim(-10, 20)
plt.xlim(-25, 15)
plt.legend(loc='upper left')
plt.title(r'2D Regression Example ($\vartheta=%.2f\%%$)' % (confidence * 100))
plt.grid()

plt.show()

# %% [markdown]
# As we can see the expectations and variances predicted by the JPT characterize this dataset well and the variance even adjusts to the different x values. Impressive!
